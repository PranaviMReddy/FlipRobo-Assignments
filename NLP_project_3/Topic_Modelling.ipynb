# %%
#importing libraries
import gensim

from nltk.stem import WordNetLemmatizer, SnowballStemmer
#creating instance for snowballstemmer
stemmer = SnowballStemmer("english")

# %%
#creating functions for processing
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token)>3:
            result.append(lemmatize_stemming(token).lower())
            
    return result

# %%
#extracting the saved text file from the directory
import glob
docs_text=[]  #store text of all documents
for files in glob.glob('*'): #all files in the present directory
    if(files.startswith('news')):
        handle = open(files,'r',encoding="utf-8",errors='ignore')
        docs_text.append(handle.read())
        handle.close()

# %%
#displaying the content of file
docs_text
# Out:
# ['Three farm bills  the Essential Commodities (Amendment) Bill, the Farmers Produce Trade and Commerce (Promotion and Facilitation) Bill (commonly referred to as the APMC Bypass Bill), and the Farmers (Empowerment and Protection) Agreement on Price Assurance and Farm Services Bill  were cleared by Parliament amid protests from the Opposition. Sudha Narayanan (Associate Professor at the Indira Gandhi Institute of Development Research) and Arindam Banerjee (Associate Professor at the School of Liberal Studies at Ambedkar University) discuss the implications of the controversial Bills in a conversation moderated by Vikas Dhoot. Edited excerpts:\nSudha Narayanan: Sometimes we say, Be careful what you wish for, you may actually get it. These Bills represent fairly important changes in marketing regulation and are what many were asking for because of the flaws in the APMC [Agricultural Produce Market Committee] system. But at the same time, they are worrying for two reasons. The first is in what they say. The Bills have lacunae: lack of regulation, regulatory oversight and reporting. Theyre somewhat non-transparent. The second is what they do not say. You cant have marketing Bills that are devoid of the larger context of State intervention in agriculture, and agricultural policy.\n\nFarmers are on their way participate in a rail roko protest at Devi Dass Pura village, near Amritsar on September 24, 2020.\nWill the farm bills give farmers a choice? \n\nThe APMC bypass Bill is the most controversial. This Bill actually assumes that private players dont exist today and the APMC is a monopoly. That is a flawed assumption. Private players actually look to the APMC for a reference price to conduct their own transactions.\n\nNow youre trying to create an alternative thats outside the APMC, which is on advantageous terms where you dont have to pay mandi fees or taxes. This could result in two perverse consequences. One is that the APMC continues to set the reference price. That makes no sense because if your private players are still looking to the APMC for a reference price, then your idea of getting rid of the inefficient APMC doesnt hold. Large-scale trade outside the mandi is bound to happen because new players will prefer to trade outside the mandi because they dont have to pay charges. APMC traders too might now prefer to operate outside the mandi for the same reason. So, if the APMC system collapses, then this Bill hasnt envisioned any alternative for a large market that can actually set price signals. So, instead of unifying the national market, you could actually have little bargaining islands where people are just setting prices. This might undermine farmer interests. And in that new trade area, there is no regulation, no data, transactions are invisible. In the current APMC system, even with its flaws, at least there is some recording and grievance redressal. The current Bill leaves too much to the benevolence of private players to give fair terms to the farmers.\n\nPrivate trade in agricultural commodities is not something new in India. At the same time, the justification for these Bills at this point of time is primarily, I think, to facilitate bigger private players into the farm sector. There are several reasons for that. The governments justification is hinged on farmers getting better prices for their produce because they are going to get greater choices. Now, the farmers, at least the big farmers, and net surplus producers dont seem convinced. The reason is that market prices or farmers incomes are not simply dependent on the market structure. Farmers organisations are concerned that other demands are being ignored, particularly during this difficult economic situation. Market prices are sluggish because demand is sluggish. Farmers incomes are actually seeing a period of stagnation. The other concern for farmers has been growing input costs. Farmers have been squeezed between rising costs of cultivation and sluggish prices ...
#  '{\n "cells": [\n  {\n   "cell_type": "code",\n   "execution_count": 1,\n   "metadata": {},\n   "outputs": [\n    {\n     "name": "stdout",\n     "output_type": "stream",\n     "text": [\n      "Requirement already satisfied: beautifulsoup4 in c:\\\\programdata\\\\anaconda3\\\\lib\\\\site-packages (4.7.1)\\n",\n      "Requirement already satisfied: soupsieve>=1.2 in c:\\\\programdata\\\\anaconda3\\\\lib\\\\site-packages (from beautifulsoup4) (1.8)\\n",\n      "Requirement already satisfied: requests in c:\\\\users\\\\pranavi\'s pc\\\\appdata\\\\roaming\\\\python\\\\python37\\\\site-packages (2.22.0)\\n",\n      "Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\\\\users\\\\pranavi\'s pc\\\\appdata\\\\roaming\\\\python\\\\python37\\\\site-packages (from requests) (1.25.8)\\n",\n      "Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\\\\users\\\\pranavi\'s pc\\\\appdata\\\\roaming\\\\python\\\\python37\\\\site-packages (from requests) (3.0.4)\\n",\n      "Requirement already satisfied: idna<2.9,>=2.5 in c:\\\\users\\\\pranavi\'s pc\\\\appdata\\\\roaming\\\\python\\\\python37\\\\site-packages (from requests) (2.8)\\n",\n      "Requirement already satisfied: certifi>=2017.4.17 in c:\\\\users\\\\pranavi\'s pc\\\\appdata\\\\roaming\\\\python\\\\python37\\\\site-packages (from requests) (2019.11.28)\\n"\n     ]\n    }\n   ],\n   "source": [\n    "! pip install beautifulsoup4\\n",\n    "! pip install requests"\n   ]\n  },\n  {\n   "cell_type": "code",\n   "execution_count": 2,\n   "metadata": {},\n   "outputs": [],\n   "source": [\n    "import requests\\n",\n    "from bs4 import BeautifulSoup\\n",\n    "import numpy as np\\n",\n    "import pandas as pd\\n",\n    "import time"\n   ]\n  },\n  {\n   "cell_type": "code",\n   "execution_count": 15,\n   "metadata": {},\n   "outputs": [],\n   "source": [\n    "# url definition\\n",\n    "url = \\"https://edition.cnn.com/world/index.html\\""\n   ]\n  },\n  {\n   "cell_type": "code",\n   "execution_count": 16,\n   "metadata": {},\n   "outputs": [\n    {\n     "data": {\n      "text/plain": [\n       "116"\n      ]\n     },\n     "execution_count": 16,\n     "metadata": {},\n     "output_type": "execute_result"\n    }\n   ],\n   "source": [\n    "# Request\\n",\n    "r1 = requests.get(url)\\n",\n    "r1.status_code\\n",\n    "\\n",\n    "# We\'ll save in coverpage the cover page content\\n",\n    "coverpage = r1.content\\n",\n    "\\n",\n    "# Soup creation\\n",\n    "soup1 = BeautifulSoup(coverpage, \'html5lib\')\\n",\n    "\\n",\n    "# News identification\\n",\n    "coverpage_news = soup1.find_all(\'h3\', class_=\'cd__headline\')\\n",\n    "len(coverpage_news)"\n   ]\n  },\n  {\n   "cell_type": "code",\n   "execution_count": 31,\n   "metadata": {},\n   "outputs": [\n    {\n     "data": {\n      "text/plain": [\n       "<h3 class=\\"cd__headline\\" data-analytics=\\"World_list-hierarchical-xs_article_\\"><a href=\\"/2020/08/07/asia/china-mongolia-bubonic-plague-death-intl-hnk-scli-scn/index.html\\"><span class=\\"cd__headline-text\\">China seals off village after bubonic plague death in Inner Mongolia</span><span class=\\"cd__headline-icon cnn-icon\\"></span></a></h3>"\n      ]\n     },\n     "execution_count": 31,\n     "metadata": {},\n     "output_type": "execute_result"\n    }\n   ],\n   "source": [\n    "coverpage_news[4]"\n   ]\n  },\n  {\n   "cell_type": "code",\n   "execution_count": 21,\n   "metadata": {},\n   "outputs": [],\n   "source": [\n    "number_of_articles = 10\\n",\n    "list_links = []\\n",\n    "for n in np.arange(0, number_of_articles):\\n",\n    "    link = coverpage_news[n].find(\'a\')[\'href\']\\n",\n    "    list_links.append(link)"\n   ]\n  },\n  {\n   "cell_type": "code",\n   "execution_count": 23,\n   "metadata": {},\n   "outputs": [],\n   "source": [\n    "df_show_info = pd.DataFrame(\\n",\n    "    {\'Article Link\': list_links})"\n   ]\n  },\n  {\n   "cell_type": "code",\n   "execution_count": 25,\n   "metadata": {},\n   " ...

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Pranavi's
# [nltk_data]     PC\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
#processing the data for tokenization and lemmatization

processed_docs = []
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text,pos='v'))

for doc in docs_text:
    processed_docs.append(preprocess(doc))
processed_docs
# Out:
# [['farm',
#   'bill',
#   'essenti',
#   'commod',
#   'amend',
#   'farmer',
#   'produc',
#   'trade',
#   'commerc',
#   'promot',
#   'facilit',
#   'common',
#   'refer',
#   'apmc',
#   'bypass',
#   'farmer',
#   'empower',
#   'protect',
#   'agreement',
#   'price',
#   'assur',
#   'farm',
#   'servic',
#   'clear',
#   'parliament',
#   'amid',
#   'protest',
#   'opposit',
#   'sudha',
#   'narayanan',
#   'associ',
#   'professor',
#   'indira',
#   'gandhi',
#   'institut',
#   'develop',
#   'research',
#   'arindam',
#   'banerje',
#   'associ',
#   'professor',
#   'school',
#   'liber',
#   'studi',
#   'ambedkar',
#   'univers',
#   'discuss',
#   'implic',
#   'controversi',
#   'bill',
#   'convers',
#   'moder',
#   'vika',
#   'dhoot',
#   'edit',
#   'excerpt',
#   'sudha',
#   'narayanan',
#   'care',
#   'wish',
#   'actual',
#   'bill',
#   'repres',
#   'fair',
#   'import',
#   'chang',
#   'market',
#   'regul',
#   'ask',
#   'flaw',
#   'apmc',
#   'agricultur',
#   'produc',
#   'market',
#   'committe',
#   'time',
#   'worri',
#   'reason',
#   'bill',
#   'lacuna',
#   'lack',
#   'regul',
#   'regulatori',
#   'oversight',
#   'report',
#   'theyr',
#   'somewhat',
#   'transpar',
#   'second',
#   'market',
#   'bill',
#   'devoid',
#   'larger',
#   'context',
#   'state',
#   'intervent',
#   'agricultur',
#   'agricultur',
#   'polici',
#   'farmer',
#   'particip',
#   'rail',
#   'roko',
#   'protest',
#   'devi',
#   'dass',
#   'pura',
#   'villag',
#   'near',
#   'amritsar',
#   'septemb',
#   'farm',
#   'bill',
#   'farmer',
#   'choic',
#   'apmc',
#   'bypass',
#   'controversi',
#   'actual',
#   'assum',
#   'privat',
#   'player',
#   'dont',
#   'exist',
#   'today',
#   'apmc',
#   'monopoli',
#   'flaw',
#   'assumpt',
#   'privat',
#   'player',
#   'actual',
#   'look',
#   'apmc',
#   'refer',
#   'price',
#   'conduct',
#   'transact',
#   'your',
#   'tri',
#   'creat',
#   'altern',
#   'that',
#   'outsid',
#   'apmc',
#   'advantag',
#   'term',
#   'dont',
#   'mandi',
#   'fee',
#   'tax',
#   'result',
#   'pervers',
#   'consequ',
#   'apmc',
#   'continu',
#   'refer',
#   'price',
#   'make',
#   'sens',
#   'privat',
#   'player',
#   'look',
#   'apmc',
#   'refer',
#   'price',
#   'idea',
#   'get',
#   'ineffici',
#   'apmc',
#   'doesnt',
#   'hold',
#   'larg',
#   'scale',
#   'trade',
#   'outsid',
#   'mandi',
#   'bind',
#   'happen',
#   'player',
#   'prefer',
#   'trade',
#   'outsid',
#   'mandi',
#   'dont',
#   'charg',
#   'apmc',
#   'trader',
#   'prefer',
#   'oper',
#   'outsid',
#   'mandi',
#   'reason',
#   'apmc',
#   'collaps',
#   'envis',
#   'altern',
#   'larg',
#   'market',
#   'actual',
#   'price',
#   'signal',
#   'instead',
#   'unifi',
#   'nation',
#   'market',
#   'actual',
#   'littl',
#   'bargain',
#   'island',
#   'peopl',
#   'set',
#   'price',
#   'undermin',
#   'farmer',
#   'interest',
#   'trade',
#   'area',
#   'regul',
#   'data',
#   'transact',
#   'invis',
#   'current',
#   'apmc',
#   'flaw',
#   'record',
#   'grievanc',
#   'redress',
#   'current',
#   'leav',
#   'benevol',
#   'privat',
#   'player',
#   'fair',
#   'term',
#   'farmer',
#   'privat',
#   'trade',
#   'agricultur',
#   'commod',
#   'india',
#   'time',
#   'justif',
#   'bill',
#   'point',
#   'time',
#   'primarili',
#   'think',
#   'facilit',
#   'bigger',
#   'privat',
#   'player',
#   'farm',
#   'sector',
#   'reason',
#   'govern',
#   'justif',
#   'hing',
#   'farmer',
#   'get',
#   'better',
#   'price',
#   'produc',
#   'go',
#   'greater',
#   'choic',
#   'farmer',
#   'farmer',
#   'surplus',
#   'produc',
#   'dont',
#   'convinc',
#   'reason',
#   'market',
#   'price',
#   'farmer',
#   'incom',
#   'simpli',
#   'depend',
#   'market',
#   'structur',
#   'farmer',
#   'organis',
#   'concern',
#   'demand',
#   'ignor',
#   'particular',
#   'difficult',
#   'econom',
#   'situat',
#   'market',
#   'price',
#   'sluggish',
#   'demand',
#   'sluggish',
#   'farmer',
#   'incom',
#   'actual',
#   'see',
#   'period',
#   'stagnat',
#   'concern',
#   'farmer',
#   'grow',
#   'input',
#   'cost',
#   'farmer',
#   'squeez',
#   'rise',
#   'cost',
#   'cultiv',
#   'sluggish',
#   'price',
#   'concern',
#   'need',
#   'intervent',
#   'govern',
#   'form',
#   'subsidi',
#   'procur',
#   'minimum',
#   'support',
#   'price',
#   'procur',
#   'major',
#   'concern',
#   'certain',
#   'polici',
#   'document',
#   'present',
#   'govern',
#   'earlier',
#   'talk',
#   'replac',
#   'food',
#   'corpor',
#   'india',
#   'cash',
#   'transfer',
#   'happen',
#   'result',
#   'facilit',
#   'player',
#   'farm',
#   'sector',
#   'farmer',
#   'better',
#   'choic',
#   'farmer',
#   'actual',
#   'start',
#   'sell',
#   'privat',
#   'player',
#   'possibl',
#   'import',
#   'apmc',
#   'procur',
#   'actual',
#   'wither',
#   'away',
#   'time',
#   'concern',
#   'everybodi',
#   'intern',
#   'weve',
#   'see',
#   'cartel',
#   'french',
#   'dairi',
#   'produc',
#   'dairi',
#   'farmer',
#   'oper',
#   'huge',
#   'player',
#   'buyer',
#   'cartel',
#   'price',
#   'that',
#   'reason',
#   'take',
#   'hard',
#   'look',
#   'suppli',
#   'chain',
#   'reduc',
#   'power',
#   'consolid',
#   'india',
#   'go',
#   'predict',
#   'player',
#   'want',
#   'minimis',
#   'cost',
#   'tradit',
#   'market',
#   'channel',
#   'resili',
#   'farmer',
#   'go',
#   'trader',
#   'multipl',
#   'reason',
#   'sale',
#   'crop',
#   'trader',
#   'extend',
#   'credit',
#   'deeper',
#   'relationship',
#   'trust',
#   'kind',
#   'qualiti',
#   'farmer',
#   'run',
#   'risk',
#   'deal',
#   'player',
#   'give',
#   'player',
#   'come',
#   'shop',
#   'crowd',
#   'player',
#   'manag',
#   'place',
#   'way',
#   'see',
#   'oper',
#   'crowd',
#   'competit',
#   'busi',
#   'posit',
#   'interact',
#   'farmer',
#   'field',
#   'staff',
#   'eventu',
#   'opt',
#   'farmer',
#   'cooper',
#   'anybodi',
#   'whos',
#   'abl',
#   'aggreg',
#   'produc',
#   'say',
#   'bill',
#   'facilit',
#   'direct',
#   'transact',
#   'farmer',
#   'see',
#   'intermedi',
#   'intermedi',
#   'compani',
#   'expens',
#   'work',
#   'larg',
#   'number',
#   'farmer',
#   'look',
#   'intermediari',
#   'aggreg',
#   'produc',
#   'look',
#   'global',
#   'experi',
#   'corpor',
#   'food',
#   'market',
#   'monopoli',
#   'duopoli',
#   'expect',
#   'happen',
#   'concern',
#   'privat',
#   'trade',
#   'agricultur',
#   'commod',
#   'exist',
#   'year',
#   'india',
#   'use',
#   'perspect',
#   'capit',
#   'pepsi',
#   'potato',
#   'valu',
#   'chain',
#   'exampl',
#   'contract',
#   'farm',
#   'think',
#   'thrust',
#   'area',
#   'grain',
#   'trade',
#   'india',
#   'procur',
#   'govern',
#   'happen',
#   'think',
#   'global',
#   'corpor',
#   'eye',
#   'grain',
#   'market',
#   'million',
#   'tonn',
#   'foodgrain',
#   'stock',
#   'clear',
#   'massiv',
#   'market',
#   'play',
#   'relat',
#   'shift',
#   'weight',
#   'govern',
#   'regul',
#   'privat',
#   'player',
#   'pandem',
#   'measur',
#   'stock',
#   'reduc',
#   'pandem',
#   'caus',
#   'massiv',
#   'disrupt',
#   'job',
#   'global',
#   'consequ',
#   'caus',
#   'massiv',
#   'disrupt',
#   'capit',
#   'profit',
#   'agricultur',
#   'good',
#   'suffer',
#   'necessari',
#   'item',
#   'consumpt',
#   'basket',
#   'chanc',
#   'reviv',
#   'demand',
#   'industri',
#   'good',
#   'servic',
#   'pandem',
#   'level',
#   'near',
#   'futur',
#   'capit',
#   'tri',
#   'agricultur',
#   'commod',
#   'trade',
#   'bigger',
#   'scale',
#   'recov',
#   'lose',
#   'profit',
#   'say',
#   'import',
#   'look',
#   'happen',
#   'ordin',
#   'pass',
#   'export',
#   'onion',
#   'farmer',
#   'get',
#   'signal',
#   'bill',
#   'fact',
#   'farmer',
#   'centric',
#   'there',
#   'bill',
#   'say',
#   'procur',
#   'polici',
#   'go',
#   'general',
#   'want',
#   'protect',
#   'interest',
#   'consum',
#   'undermin',
#   'interest',
#   'farmer',
#   'array',
#   'polici',
#   'work',
#   'go',
#   'essenti',
#   'commod',
#   'influenc',
#   'consum',
#   'price',
#   'polici',
#   'hurt',
#   'farmer',
#   'form',
#   'respons',
#   'signific',
#   'food',
#   'shortag',
#   'countri',
#   'point',
#   'progress',
#   'food',
#   'product',
#   'earli',
#   'face',
#   'food',
#   'shortag',
#   'mean',
#   'problem',
#   'hunger',
#   'address',
#   'continu',
#   'persist',
#   'distribut',
#   'foodgrain',
#   'happen',
#   'spite',
#   'recognis',
#   'differ',
#   'polit',
#   'econom',
#   'regim',
#   'time',
#   'post',
#   'liberalis',
#   'privat',
#   'player',
#   'capit',
#   'greater',
#   'role',
#   'play',
#   'economi',
#   'fine',
#   'need',
#   'regul',
#   'player',
#   'today',
#   'perceiv',
#   'concern',
#   'govern',
#   'public',
#   'procur',
#   'valid',
#   'demand',
#   'includ',
#   'claus',
#   'procur',
#   'mayb',
#   'bring',
#   'quell',
#   'fear',
#   'give',
#   'bill',
#   'problemat',
#   'wouldnt',
#   'want',
#   'claus',
#   'introduc',
#   'bill',
#   'flaw',
#   'think',
#   'way',
#   'fix',
#   'think',
#   'question',
#   'larger',
#   'complex',
#   'deserv',
#   'consult',
#   'process',
#   'dedic',
#   'compat',
#   'want',
#   'privat',
#   'player',
#   'insist',
#   'price',
#   'deal',
#   'that',
#   'go',
#   'self',
#   'defeat',
#   'privat',
#   'particip',
#   'reason',
#   'separ',
#   'question',
#   'farmer',
#   'punjab',
#   'disagre',
#   'farmer',
#   'bihar',
#   'go',
#   'enforc',
#   'interest',
#   'suggest',
#   'suggest',
#   'apmc',
#   'function',
#   'regim',
#   'ensur',
#   'bid',
#   'start',
#   'ensur',
#   'start',
#   'floor',
#   'price',
#   'weve',
#   'lose',
#   'opportun',
#   'apmc',
#   'outsid',
#   'want',
#   'make',
#   'sens',
#   'actual',
#   'forc',
#   'govern',
#   'procur',
#   'need',
#   'like',
#   'china',
#   'decad',
#   'distribut',
#   'countri',
#   'export',
#   'plan',
#   'distribut',
#   'econom',
#   'sens',
#   'govern',
#   'go',
#   'respons',
#   'go',
#   'geograph',
#   'distribut',
#   'crop',
#   'legisl',
#   'need',
#   'discuss',
#   'differ',
#   'aspect'],
#  ['cell',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'metadata',
#   'output',
#   'stdout',
#   'output_typ',
#   'stream',
#   'text',
#   'requir',
#   'satisfi',
#   'beautifulsoup',
#   'programdata',
#   'anaconda',
#   'site',
#   'packag',
#   'requir',
#   'satisfi',
#   'soupsiev',
#   'programdata',
#   'anaconda',
#   'site',
#   'packag',
#   'beautifulsoup',
#   'requir',
#   'satisfi',
#   'request',
#   'user',
#   'pranavi',
#   'appdata',
#   'roam',
#   'python',
#   'python',
#   'site',
#   'packag',
#   'requir',
#   'satisfi',
#   'urllib',
#   'user',
#   'pranavi',
#   'appdata',
#   'roam',
#   'python',
#   'python',
#   'site',
#   'packag',
#   'request',
#   'requir',
#   'satisfi',
#   'chardet',
#   'user',
#   'pranavi',
#   'appdata',
#   'roam',
#   'python',
#   'python',
#   'site',
#   'packag',
#   'request',
#   'requir',
#   'satisfi',
#   'idna',
#   'user',
#   'pranavi',
#   'appdata',
#   'roam',
#   'python',
#   'python',
#   'site',
#   'packag',
#   'request',
#   'requir',
#   'satisfi',
#   'certifi',
#   'user',
#   'pranavi',
#   'appdata',
#   'roam',
#   'python',
#   'python',
#   'site',
#   'packag',
#   'request',
#   'sourc',
#   'instal',
#   'beautifulsoup',
#   'instal',
#   'request',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'metadata',
#   'output',
#   'sourc',
#   'import',
#   'request',
#   'import',
#   'beautifulsoup',
#   'import',
#   'numpi',
#   'import',
#   'panda',
#   'import',
#   'time',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'metadata',
#   'output',
#   'sourc',
#   'definit',
#   'https',
#   'edit',
#   'world',
#   'index',
#   'html',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'metadata',
#   'output',
#   'data',
#   'text',
#   'plain',
#   'execution_count',
#   'metadata',
#   'output_typ',
#   'execute_result',
#   'sourc',
#   'request',
#   'request',
#   'status_cod',
#   'save',
#   'coverpag',
#   'cover',
#   'page',
#   'content',
#   'coverpag',
#   'content',
#   'soup',
#   'creation',
#   'soup',
#   'beautifulsoup',
#   'coverpag',
#   'html',
#   'news',
#   'identif',
#   'coverpage_new',
#   'soup',
#   'find_al',
#   'class_',
#   'cd__headlin',
#   'coverpage_new',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'metadata',
#   'output',
#   'data',
#   'text',
#   'plain',
#   'class',
#   'cd__headlin',
#   'data',
#   'analyt',
#   'world_list',
#   'hierarch',
#   'xs_article_',
#   'href',
#   'asia',
#   'china',
#   'mongolia',
#   'bubon',
#   'plagu',
#   'death',
#   'intl',
#   'scli',
#   'index',
#   'html',
#   'span',
#   'class',
#   'cd__headlin',
#   'text',
#   'china',
#   'seal',
#   'villag',
#   'bubon',
#   'plagu',
#   'death',
#   'inner',
#   'mongolia',
#   'span',
#   'span',
#   'class',
#   'cd__headlin',
#   'icon',
#   'icon',
#   'span',
#   'execution_count',
#   'metadata',
#   'output_typ',
#   'execute_result',
#   'sourc',
#   'coverpage_new',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'metadata',
#   'output',
#   'sourc',
#   'list_link',
#   'arang',
#   'link',
#   'coverpage_new',
#   'href',
#   'list_link',
#   'append',
#   'link',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'metadata',
#   'output',
#   'sourc',
#   'df_show_info',
#   'datafram',
#   'articl',
#   'link',
#   'list_link',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'metadata',
#   'output',
#   'data',
#   'text',
#   'html',
#   'style',
#   'type',
#   'text',
#   'tabl',
#   'datafram',
#   'tabl',
#   'datafram',
#   'border',
#   'black',
#   'solid',
#   'import',
#   'color',
#   'black',
#   'import',
#   'style',
#   'text',
#   'plain',
#   'ipython',
#   'core',
#   'display',
#   'html',
#   'object',
#   'metadata',
#   'output_typ',
#   'display_data',
#   'sourc',
#   'html',
#   'style',
#   'type',
#   'text',
#   'tabl',
#   'datafram',
#   'tabl',
#   'datafram',
#   'border',
#   'black',
#   'solid',
#   'import',
#   'color',
#   'black',
#   'import',
#   'style',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'metadata',
#   'output',
#   'data',
#   'text',
#   'html',
#   'style',
#   'scope',
#   'datafram',
#   'tbodi',
#   'type',
#   'vertic',
#   'align',
#   'middl',
#   'datafram',
#   'tbodi',
#   'vertic',
#   'align',
#   'datafram',
#   'thead',
#   'text',
#   'align',
#   'right',
#   'style',
#   'tabl',
#   'border',
#   'class',
#   'datafram',
#   'thead',
#   'style',
#   'text',
#   'align',
#   'right',
#   'articl',
#   'link',
#   'thead',
#   'tbodi',
#   'middleeast',
#   'lebanon',
#   'explos',
#   'mini',
#   'world',
#   'beirut',
#   'explos',
#   'survivor',
#   'video',
#   'world',
#   'beirut',
#   'blast',
#   'eyewitn',
#   'asia',
#   'india',
#   'coronavirus',
#   'million',
#   'asia',
#   'china',
#   'mongolia',
#   'bubon',
#   'plagu',
#   'europ',
#   'itali',
#   'school',
#   'return',
#   'saw',
#   'europ',
#   'muslim',
#   'coronavirus',
#   'england',
#   'europ',
#   'lebanon',
#   'russian',
#   'ship',
#   'blast',
#   'middleeast',
#   'beirut',
#   'explos',
#   'anger',
#   'middleeast',
#   'live',
#   'news',
#   'lebanon',
#   'beirut',
#   'explos',
#   'tbodi',
#   'tabl',
#   'text',
#   'plain',
#   'articl',
#   'link',
#   'middleeast',
#   'lebanon',
#   'explos',
#   'mini',
#   'world',
#   'beirut',
#   'explos',
#   'survivor',
#   'video',
#   'world',
#   'beirut',
#   'blast',
#   'eyewitn',
#   'asia',
#   'india',
#   'coronavirus',
#   'million',
#   'asia',
#   'china',
#   'mongolia',
#   'bubon',
#   'plagu',
#   'europ',
#   'itali',
#   'school',
#   'return',
#   'saw',
#   'europ',
#   'muslim',
#   'coronavirus',
#   'england',
#   'europ',
#   'lebanon',
#   'russian',
#   'ship',
#   'blast',
#   'middleeast',
#   'beirut',
#   'explos',
#   'anger',
#   'middleeast',
#   'live',
#   'news',
#   'lebanon',
#   'beirut',
#   'explos',
#   'execution_count',
#   'metadata',
#   'output_typ',
#   'execute_result',
#   'sourc',
#   'df_show_info',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'metadata',
#   'output',
#   'sourc',
#   'list_titl',
#   'arang',
#   'titl',
#   'coverpage_new',
#   'span',
#   'get_text',
#   'list_titl',
#   'append',
#   'titl',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'metadata',
#   'output',
#   'sourc',
#   'df_show_info',
#   'df_show_info',
#   'datafram',
#   'articl',
#   'titl',
#   'list_titl',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'metadata',
#   'output',
#   'data',
#   'text',
#   'html',
#   'style',
#   'type',
#   'text',
#   'tabl',
#   'datafram',
#   'tabl',
#   'datafram',
#   'border',
#   'black',
#   'solid',
#   'import',
#   'color',
#   'black',
#   'import',
#   'style',
#   'text',
#   'plain',
#   'ipython',
#   'core',
#   'display',
#   'html',
#   'object',
#   'metadata',
#   'output_typ',
#   'display_data',
#   'sourc',
#   'html',
#   'style',
#   'type',
#   'text',
#   'tabl',
#   'datafram',
#   'tabl',
#   'datafram',
#   'border',
#   'black',
#   'solid',
#   'import',
#   'color',
#   'black',
#   'import',
#   'style',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'metadata',
#   'output',
#   'data',
#   'text',
#   'html',
#   'style',
#   'scope',
#   'datafram',
#   'tbodi',
#   'type',
#   'vertic',
#   'align',
#   'middl',
#   'datafram',
#   'tbodi',
#   'vertic',
#   'align',
#   'datafram',
#   'thead',
#   'text',
#   'align',
#   'right',
#   'style',
#   'tabl',
#   'border',
#   'class',
#   'datafram',
#   'thead',
#   'style',
#   'text',
#   'align',
#   'right',
#   'articl',
#   'titl',
#   'thead',
#   'tbodi',
#   'judg',
#   'warn',
#   'danger',
#   'cargo',
#   'store',
#   'coupl',
#   'stand',
#   'meter',
#   'blas',
#   'massacr',
#   'hear',
#   'wit',
#   'india',
#   'million',
#   'confirm',
#   'china',
#   'seal',
#   'villag',
#   'bubon',
#   'plagu',
#   'itali',
#   'prepar',
#   'return',
#   'school',
#   'saw',
#   'latest',
#   'sign',
#   'covid',
#   'relat',
#   'racism',
#   'russian',
#   'ship',
#   'cargo',
#   'danger',
#   'ammonium',
#   'beirut',
#   'port',
#   'employe',
#   'detain',
#   'investigatio',
#   'beirut',
#   'explos',
#   'rock',
#   'lebanon',
#   'capit',
#   'citi',
#   'tbodi',
#   'tabl',
#   'text',
#   'plain',
#   'articl',
#   'titl',
#   'judg',
#   'warn',
#   'danger',
#   'cargo',
#   'store',
#   'coupl',
#   'stand',
#   'meter',
#   'blas',
#   'massacr',
#   'hear',
#   'wit',
#   'india',
#   'million',
#   'confirm',
#   'china',
#   'seal',
#   'villag',
#   'bubon',
#   'plagu',
#   'itali',
#   'prepar',
#   'return',
#   'school',
#   'saw',
#   'latest',
#   'sign',
#   'covid',
#   'relat',
#   'racism',
#   'russian',
#   'ship',
#   'cargo',
#   'danger',
#   'ammonium',
#   'beirut',
#   'port',
#   'employe',
#   'detain',
#   'investigatio',
#   'beirut',
#   'explos',
#   'rock',
#   'lebanon',
#   'capit',
#   'citi',
#   'execution_count',
#   'metadata',
#   'output_typ',
#   'execute_result',
#   'sourc',
#   'df_show_info',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'metadata',
#   'output',
#   'enam',
#   'missingschema',
#   'evalu',
#   'invalid',
#   'middleeast',
#   'live',
#   'news',
#   'lebanon',
#   'beirut',
#   'explos',
#   'live',
#   'updat',
#   'intl',
#   'index',
#   'html',
#   'schema',
#   'suppli',
#   'mean',
#   'http',
#   'middleeast',
#   'live',
#   'news',
#   'lebanon',
#   'beirut',
#   'explos',
#   'live',
#   'updat',
#   'intl',
#   'index',
#   'html',
#   'output_typ',
#   'error',
#   'traceback',
#   'mmissingschema',
#   'traceback',
#   'recent',
#   'ipython',
#   'input',
#   'modul',
#   'mfor',
#   'marang',
#   'read',
#   'content',
#   'divid',
#   'paragraph',
#   'marticl',
#   'mrequest',
#   'mget',
#   'mlink',
#   'marticl',
#   'mcontent',
#   'msoup_articl',
#   'mbeautifulsoup',
#   'html',
#   'appdata',
#   'roam',
#   'python',
#   'python',
#   'site',
#   'packag',
#   'request',
#   'mget',
#   'param',
#   'kwarg',
#   'mkwarg',
#   'msetdefault',
#   'allow_redirect',
#   'mtrue',
#   'mreturn',
#   'mrequest',
#   'murl',
#   'mparam',
#   'mparam',
#   'mkwarg',
#   'appdata',
#   'roam',
#   'python',
#   'python',
#   'site',
#   'packag',
#   'request',
#   'mrequest',
#   'method',
#   'kwarg',
#   'case',
#   'look',
#   'like',
#   'memori',
#   'leak',
#   'mwith',
#   'msession',
#   'msession',
#   'msession',
#   'mreturn',
#   'msession',
#   'mrequest',
#   'mmethod',
#   'mmethod',
#   'murl',
#   'murl',
#   'mkwarg',
#   'appdata',
#   'roam',
#   'python',
#   'python',
#   'site',
#   'packag',
#   'request',
#   'session',
#   'mrequest',
#   'self',
#   'method',
#   'param',
#   'data',
#   'header',
#   'cooki',
#   'file',
#   'auth',
#   'timeout',
#   'allow_redirect',
#   'proxi',
#   'hook',
#   'stream',
#   'verifi',
#   'cert',
#   'json',
#   'mhook',
#   'mhook',
#   'mprep',
#   'mself',
#   'mreq',
#   'mproxi',
#   'mproxi',
#   'appdata',
#   'roam',
#   'python',
#   'python',
#   'site',
#   'packag',
#   'request',
#   'session',
#   'self',
#   'request',
#   'mauth',
#   'mmerge_set',
#   'mauth',
#   'mself',
#   'mauth',
#   'mcooki',
#   'mmerged_cooki',
#   'mhook',
#   'mmerge_hook',
#   'mrequest',
#   'mhook',
#   'mself',
#   'mhook',
#   'mreturn',
#   'appdata',
#   'roam',
#   'python',
#   'python',
#   'site',
#   'packag',
#   'request',
#   'model',
#   'mprepar',
#   'self',
#   'method',
#   'header',
#   'file',
#   'data',
#   'param',
#   'auth',
#   'cooki',
#   'hook',
#   'json',
#   'mself',
#   'mprepare_method',
#   'mmethod',
#   'mself',
#   'mprepare_url',
#   'murl',
#   'mparam',
#   'mself',
#   'mheader',
#   'mself',
#   'mcooki',
#   'appdata',
#   'roam',
#   'python',
#   'python',
#   'site',
#   'packag',
#   'request',
#   'model',
#   'mprepare_url',
#   'self',
#   'param',
#   'merror',
#   'merror',
#   'mformat',
#   'murl',
#   'mrais',
#   'mmissingschema',
#   'merror',
#   'mnot',
#   'mhost',
#   'mmissingschema',
#   'invalid',
#   'middleeast',
#   'live',
#   'news',
#   'lebanon',
#   'beirut',
#   'explos',
#   'live',
#   'updat',
#   'intl',
#   'index',
#   'html',
#   'schema',
#   'suppli',
#   'mean',
#   'http',
#   'middleeast',
#   'live',
#   'news',
#   'lebanon',
#   'beirut',
#   'explos',
#   'live',
#   'updat',
#   'intl',
#   'index',
#   'html',
#   'sourc',
#   'news_cont',
#   'arang',
#   'read',
#   'content',
#   'divid',
#   'paragraph',
#   'articl',
#   'request',
#   'link',
#   'article_cont',
#   'articl',
#   'content',
#   'soup_articl',
#   'beautifulsoup',
#   'article_cont',
#   'html',
#   'bodi',
#   'soup_articl',
#   'find_al',
#   'class_',
#   'contain',
#   'bodi',
#   'find_al',
#   'unifi',
#   'paragraph',
#   'list_paragraph',
#   'arang',
#   'paragraph',
#   'get_text',
#   'list_paragraph',
#   'append',
#   'paragraph',
#   'final_articl',
#   'join',
#   'list_paragraph',
#   'news_cont',
#   'append',
#   'final_articl',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'null',
#   'metadata',
#   'output',
#   'sourc',
#   'df_featur',
#   'datafram',
#   'articl',
#   'content',
#   'news_cont',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'null',
#   'metadata',
#   'output',
#   'sourc',
#   'df_show_info',
#   'datafram',
#   'articl',
#   'content',
#   'news_cont',
#   'cell_typ',
#   'code',
#   'execution_count',
#   'metadata',
#   'output',
#   'enam',
#   'missingschema',
#   'evalu',
#   'invalid',
#   'middleeast',
#   'lebanon',
#   'explos',
#   'ministri',
#   'justic',
#   'intl',
#   'index',
#   'html',
#   'schema',
#   'suppli',
#   'mean',
#   'http',
#   'middleeast',
#   'lebanon',
#   'explos',
#   'ministri',
#   'justic',
#   'intl',
#   'index',
#   'html',
#   'output_typ',
#   'error',
#   'traceback',
#   'mmissingschema',
#   'traceback',
#   'recent',
#   'ipython',
#   'input',
#   'modul',
#   'read',
#   'content',
#   'divid',
#   'paragraph',
#   'marticl',
#   'mrequest',
#   'mget',
#   'mlink',
#   'marticl',
#   'mcontent',
#   'msoup_articl',
#   'mbeautifulsoup',
#   'html',
#   'appdata',
#   'roam',
#   'python',
#   ...]]

# %%
#bag of words on the data set
dictionary = gensim.corpora.Dictionary(processed_docs)

# %%
print (dictionary)
# Out:
# Dictionary(640 unique tokens: ['abl', 'actual', 'address', 'advantag', 'aggreg']...)

# %%
#Create the Bag-of-words model for each document i.e for each document we create a dictionary reporting how many
#words and how many times those words appear. Save this to 'bow_corpus'
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# %%
#displaying the corpus saved
bow_corpus
# Out:
# [[(0, 1),
#   (1, 9),
#   (2, 1),
#   (3, 1),
#   (4, 2),
#   (5, 1),
#   (6, 7),
#   (7, 2),
#   (8, 1),
#   (9, 1),
#   (10, 1),
#   (11, 1),
#   (12, 1),
#   (13, 15),
#   (14, 2),
#   (15, 1),
#   (16, 1),
#   (17, 1),
#   (18, 1),
#   (19, 2),
#   (20, 1),
#   (21, 1),
#   (22, 1),
#   (23, 1),
#   (24, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 2),
#   (29, 1),
#   (30, 2),
#   (31, 1),
#   (32, 12),
#   (33, 1),
#   (34, 1),
#   (35, 1),
#   (36, 1),
#   (37, 2),
#   (38, 4),
#   (39, 1),
#   (40, 2),
#   (41, 1),
#   (42, 2),
#   (43, 1),
#   (44, 1),
#   (45, 2),
#   (46, 1),
#   (47, 1),
#   (48, 1),
#   (49, 1),
#   (50, 1),
#   (51, 3),
#   (52, 2),
#   (53, 2),
#   (54, 1),
#   (55, 1),
#   (56, 1),
#   (57, 1),
#   (58, 5),
#   (59, 1),
#   (60, 1),
#   (61, 1),
#   (62, 1),
#   (63, 1),
#   (64, 7),
#   (65, 1),
#   (66, 2),
#   (67, 1),
#   (68, 1),
#   (69, 2),
#   (70, 1),
#   (71, 1),
#   (72, 2),
#   (73, 1),
#   (74, 2),
#   (75, 1),
#   (76, 1),
#   (77, 1),
#   (78, 3),
#   (79, 3),
#   (80, 2),
#   (81, 1),
#   (82, 1),
#   (83, 2),
#   (84, 2),
#   (85, 1),
#   (86, 2),
#   (87, 2),
#   (88, 1),
#   (89, 1),
#   (90, 2),
#   (91, 1),
#   (92, 1),
#   (93, 1),
#   (94, 1),
#   (95, 4),
#   (96, 1),
#   (97, 1),
#   (98, 1),
#   (99, 1),
#   (100, 1),
#   (101, 1),
#   (102, 2),
#   (103, 1),
#   (104, 1),
#   (105, 1),
#   (106, 2),
#   (107, 2),
#   (108, 4),
#   (109, 1),
#   (110, 1),
#   (111, 4),
#   (112, 1),
#   (113, 1),
#   (114, 1),
#   (115, 3),
#   (116, 1),
#   (117, 1),
#   (118, 1),
#   (119, 1),
#   (120, 2),
#   (121, 1),
#   (122, 2),
#   (123, 1),
#   (124, 1),
#   (125, 1),
#   (126, 1),
#   (127, 2),
#   (128, 1),
#   (129, 1),
#   (130, 1),
#   (131, 2),
#   (132, 1),
#   (133, 1),
#   (134, 1),
#   (135, 4),
#   (136, 1),
#   (137, 2),
#   (138, 6),
#   (139, 29),
#   (140, 1),
#   (141, 1),
#   (142, 1),
#   (143, 1),
#   (144, 1),
#   (145, 4),
#   (146, 1),
#   (147, 5),
#   (148, 2),
#   (149, 1),
#   (150, 2),
#   (151, 1),
#   (152, 1),
#   (153, 1),
#   (154, 1),
#   (155, 1),
#   (156, 1),
#   (157, 3),
#   (158, 2),
#   (159, 3),
#   (160, 9),
#   (161, 2),
#   (162, 8),
#   (163, 2),
#   (164, 2),
#   (165, 1),
#   (166, 1),
#   (167, 6),
#   (168, 1),
#   (169, 1),
#   (170, 1),
#   (171, 1),
#   (172, 1),
#   (173, 1),
#   (174, 1),
#   (175, 1),
#   (176, 1),
#   (177, 3),
#   (178, 1),
#   (179, 2),
#   (180, 5),
#   (181, 1),
#   (182, 1),
#   (183, 1),
#   (184, 1),
#   (185, 1),
#   (186, 1),
#   (187, 1),
#   (188, 1),
#   (189, 1),
#   (190, 4),
#   (191, 2),
#   (192, 1),
#   (193, 1),
#   (194, 2),
#   (195, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (199, 1),
#   (200, 2),
#   (201, 1),
#   (202, 1),
#   (203, 1),
#   (204, 3),
#   (205, 2),
#   (206, 1),
#   (207, 1),
#   (208, 1),
#   (209, 1),
#   (210, 1),
#   (211, 1),
#   (212, 1),
#   (213, 6),
#   (214, 2),
#   (215, 1),
#   (216, 2),
#   (217, 1),
#   (218, 4),
#   (219, 12),
#   (220, 3),
#   (221, 1),
#   (222, 1),
#   (223, 1),
#   (224, 1),
#   (225, 1),
#   (226, 1),
#   (227, 1),
#   (228, 2),
#   (229, 1),
#   (230, 2),
#   (231, 1),
#   (232, 2),
#   (233, 1),
#   (234, 4),
#   (235, 1),
#   (236, 1),
#   (237, 3),
#   (238, 1),
#   (239, 1),
#   (240, 1),
#   (241, 1),
#   (242, 1),
#   (243, 5),
#   (244, 1),
#   (245, 3),
#   (246, 1),
#   (247, 2),
#   (248, 1),
#   (249, 1),
#   (250, 1),
#   (251, 1),
#   (252, 1),
#   (253, 1),
#   (254, 1),
#   (255, 1),
#   (256, 1),
#   (257, 1),
#   (258, 1),
#   (259, 2),
#   (260, 17),
#   (261, 2),
#   (262, 5),
#   (263, 1),
#   (264, 1),
#   (265, 1),
#   (266, 1),
#   (267, 1),
#   (268, 1),
#   (269, 1),
#   (270, 2),
#   (271, 1),
#   (272, 15),
#   (273, 1),
#   (274, 12),
#   (275, 1),
#   (276, 1),
#   (277, 1),
#   (278, 8),
#   (279, 7),
#   (280, 1),
#   (281, 2),
#   (282, 2),
#   (283, 1),
#   (284, 1),
#   (285, 2),
#   (286, 2),
#   (287, 1),
#   (288, 1),
#   (289, 1),
#   (290, 1),
#   (291, 1),
#   (292, 2),
#   (293, 1),
#   (294, 7),
#   (295, 1),
#   (296, 1),
#   (297, 1),
#   (298, 1),
#   (299, 2),
#   (300, 4),
#   (301, 2),
#   (302, 5),
#   (303, 1),
#   (304, 1),
#   (305, 1),
#   (306, 1),
#   (307, 1),
#   (308, 1),
#   (309, 1),
#   (310, 1),
#   (311, 2),
#   (312, 2),
#   (313, 1),
#   (314, 1),
#   (315, 1),
#   (316, 1),
#   (317, 1),
#   (318, 1),
#   (319, 1),
#   (320, 3),
#   (321, 2),
#   (322, 1),
#   (323, 1),
#   (324, 2),
#   (325, 4),
#   (326, 1),
#   (327, 1),
#   (328, 3),
#   (329, 1),
#   (330, 1),
#   (331, 2),
#   (332, 1),
#   (333, 1),
#   (334, 1),
#   (335, 2),
#   (336, 2),
#   (337, 1),
#   (338, 1),
#   (339, 1),
#   (340, 3),
#   (341, 1),
#   (342, 1),
#   (343, 1),
#   (344, 1),
#   (345, 1),
#   (346, 3),
#   (347, 1),
#   (348, 2),
#   (349, 1),
#   (350, 1),
#   (351, 1),
#   (352, 2),
#   (353, 1),
#   (354, 2),
#   (355, 1),
#   (356, 1),
#   (357, 1),
#   (358, 1),
#   (359, 1),
#   (360, 1),
#   (361, 2),
#   (362, 3),
#   (363, 1),
#   (364, 1),
#   (365, 5),
#   (366, 1),
#   (367, 5),
#   (368, 2),
#   (369, 1),
#   (370, 8),
#   (371, 3),
#   (372, 1),
#   (373, 3),
#   (374, 1),
#   (375, 1),
#   (376, 2),
#   (377, 1),
#   (378, 2),
#   (379, 1),
#   (380, 1),
#   (381, 1),
#   (382, 1),
#   (383, 1),
#   (384, 1),
#   (385, 1),
#   (386, 5),
#   (387, 2),
#   (388, 1),
#   (389, 2),
#   (390, 1),
#   (391, 1),
#   (392, 1),
#   (393, 2),
#   (394, 1),
#   (395, 1),
#   (396, 1),
#   (397, 1)],
#  [(38, 2),
#   (50, 6),
#   (72, 1),
#   (89, 11),
#   (117, 1),
#   (157, 2),
#   (177, 13),
#   (180, 4),
#   (185, 2),
#   (211, 2),
#   (213, 2),
#   (222, 4),
#   (224, 4),
#   (304, 2),
#   (322, 4),
#   (326, 8),
#   (355, 4),
#   (367, 1),
#   (379, 2),
#   (385, 3),
#   (398, 1),
#   (399, 8),
#   (400, 4),
#   (401, 2),
#   (402, 2),
#   (403, 1),
#   (404, 2),
#   (405, 17),
#   (406, 8),
#   (407, 6),
#   (408, 14),
#   (409, 4),
#   (410, 5),
#   (411, 4),
#   (412, 7),
#   (413, 16),
#   (414, 8),
#   (415, 2),
#   (416, 4),
#   (417, 4),
#   (418, 6),
#   (419, 6),
#   (420, 4),
#   (421, 2),
#   (422, 4),
#   (423, 1),
#   (424, 18),
#   (425, 2),
#   (426, 1),
#   (427, 1),
#   (428, 2),
#   (429, 5),
#   (430, 3),
#   (431, 18),
#   (432, 1),
#   (433, 4),
#   (434, 2),
#   (435, 2),
#   (436, 11),
#   (437, 4),
#   (438, 2),
#   (439, 4),
#   (440, 2),
#   (441, 1),
#   (442, 3),
#   (443, 8),
#   (444, 2),
#   (445, 1),
#   (446, 4),
#   (447, 20),
#   (448, 2),
#   (449, 1),
#   (450, 2),
#   (451, 1),
#   (452, 6),
#   (453, 2),
#   (454, 2),
#   (455, 1),
#   (456, 4),
#   (457, 2),
#   (458, 2),
#   (459, 2),
#   (460, 2),
#   (461, 6),
#   (462, 2),
#   (463, 4),
#   (464, 22),
#   (465, 18),
#   (466, 2),
#   (467, 4),
#   (468, 1),
#   (469, 4),
#   (470, 5),
#   (471, 4),
#   (472, 4),
#   (473, 2),
#   (474, 1),
#   (475, 4),
#   (476, 4),
#   (477, 23),
#   (478, 4),
#   (479, 1),
#   (480, 2),
#   (481, 1),
#   (482, 1),
#   (483, 10),
#   (484, 1),
#   (485, 1),
#   (486, 2),
#   (487, 9),
#   (488, 4),
#   (489, 2),
#   (490, 6),
#   (491, 4),
#   (492, 2),
#   (493, 4),
#   (494, 2),
#   (495, 4),
#   (496, 1),
#   (497, 4),
#   (498, 1),
#   (499, 1),
#   (500, 2),
#   (501, 2),
#   (502, 16),
#   (503, 11),
#   (504, 1),
#   (505, 5),
#   (506, 6),
#   (507, 5),
#   (508, 10),
#   (509, 1),
#   (510, 4),
#   (511, 2),
#   (512, 6),
#   (513, 2),
#   (514, 2),
#   (515, 4),
#   (516, 2),
#   (517, 6),
#   (518, 25),
#   (519, 2),
#   (520, 6),
#   (521, 1),
#   (522, 2),
#   (523, 4),
#   (524, 2),
#   (525, 10),
#   (526, 2),
#   (527, 2),
#   (528, 14),
#   (529, 1),
#   (530, 2),
#   (531, 4),
#   (532, 2),
#   (533, 6),
#   (534, 2),
#   (535, 2),
#   (536, 2),
#   (537, 2),
#   (538, 6),
#   (539, 6),
#   (540, 2),
#   (541, 4),
#   (542, 2),
#   (543, 4),
#   (544, 6),
#   (545, 2),
#   (546, 2),
#   (547, 2),
#   (548, 4),
#   (549, 4),
#   (550, 2),
#   (551, 2),
#   (552, 12),
#   (553, 6),
#   (554, 14),
#   (555, 8),
#   (556, 2),
#   (557, 2),
#   (558, 2),
#   (559, 10),
#   (560, 2),
#   (561, 2),
#   (562, 1),
#   (563, 1),
#   (564, 8),
#   (565, 6),
#   (566, 3),
#   (567, 1),
#   (568, 2),
#   (569, 18),
#   (570, 9),
#   (571, 19),
#   (572, 1),
#   (573, 1),
#   (574, 10),
#   (575, 8),
#   (576, 6),
#   (577, 6),
#   (578, 2),
#   (579, 5),
#   (580, 2),
#   (581, 2),
#   (582, 2),
#   (583, 1),
#   (584, 40),
#   (585, 2),
#   (586, 4),
#   (587, 2),
#   (588, 25),
#   (589, 7),
#   (590, 4),
#   (591, 4),
#   (592, 17),
#   (593, 2),
#   (594, 4),
#   (595, 7),
#   (596, 1),
#   (597, 4),
#   (598, 4),
#   (599, 1),
#   (600, 2),
#   (601, 3),
#   (602, 4),
#   (603, 4),
#   (604, 2),
#   (605, 19),
#   (606, 4),
#   (607, 3),
#   (608, 4),
#   (609, 1),
#   (610, 18),
#   (611, 5),
#   (612, 2),
#   (613, 1),
#   (614, 1),
#   (615, 2),
#   (616, 3),
#   (617, 14),
#   (618, 2),
#   (619, 12),
#   (620, 8),
#   (621, 21),
#   (622, 6),
#   (623, 1),
#   (624, 2),
#   (625, 9),
#   (626, 4),
#   (627, 6),
#   (628, 4),
#   (629, 1),
#   (630, 5),
#   (631, 2),
#   (632, 2),
#   (633, 4),
#   (634, 2),
#   (635, 2),
#   (636, 2),
#   (637, 5),
#   (638, 1),
#   (639, 1)]]

# %%
#creating the model for topic modelling
lda_model =  gensim.models.ldamodel.LdaModel(bow_corpus, num_topics =20,id2word = dictionary,passes = 4,random_state=100,
                                           update_every=1,)

# %%
for idx, topic in lda_model.print_topics():
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.010*"farmer" + 0.007*"price" + 0.006*"apmc" + 0.006*"player" + 0.005*"market" + 0.005*"bill" + 0.004*"procur" + 0.004*"actual" + 0.004*"go" + 0.004*"govern"
#
#
# Topic: 1
# Words: 0.008*"python" + 0.006*"metadata" + 0.006*"output" + 0.006*"cell_typ" + 0.006*"text" + 0.006*"html" + 0.006*"site" + 0.006*"datafram" + 0.005*"request" + 0.005*"roam"
#
#
# Topic: 2
# Words: 0.004*"python" + 0.004*"metadata" + 0.004*"html" + 0.004*"text" + 0.003*"request" + 0.003*"execution_count" + 0.003*"datafram" + 0.003*"farmer" + 0.003*"roam" + 0.003*"cell_typ"
#
#
# Topic: 3
# Words: 0.005*"farmer" + 0.004*"bill" + 0.004*"price" + 0.004*"player" + 0.004*"apmc" + 0.003*"go" + 0.003*"privat" + 0.003*"actual" + 0.003*"python" + 0.003*"govern"
#
#
# Topic: 4
# Words: 0.031*"python" + 0.020*"metadata" + 0.019*"request" + 0.018*"html" + 0.017*"execution_count" + 0.016*"text" + 0.015*"datafram" + 0.015*"site" + 0.015*"packag" + 0.014*"output"
#
#
# Topic: 5
# Words: 0.006*"python" + 0.005*"html" + 0.005*"execution_count" + 0.005*"text" + 0.005*"request" + 0.004*"metadata" + 0.004*"datafram" + 0.004*"packag" + 0.004*"beirut" + 0.004*"roam"
#
#
# Topic: 6
# Words: 0.007*"python" + 0.006*"request" + 0.005*"lebanon" + 0.005*"farmer" + 0.005*"html" + 0.005*"packag" + 0.004*"text" + 0.004*"execution_count" + 0.004*"cell_typ" + 0.004*"code"
#
#
# Topic: 7
# Words: 0.037*"farmer" + 0.022*"player" + 0.019*"apmc" + 0.019*"price" + 0.015*"market" + 0.015*"privat" + 0.015*"bill" + 0.011*"actual" + 0.011*"go" + 0.010*"govern"
#
#
# Topic: 8
# Words: 0.006*"farmer" + 0.005*"player" + 0.004*"price" + 0.004*"bill" + 0.003*"privat" + 0.003*"apmc" + 0.003*"market" + 0.003*"actual" + 0.003*"india" + 0.003*"look"
#
#
# Topic: 9
# Words: 0.005*"python" + 0.005*"farmer" + 0.005*"datafram" + 0.005*"execution_count" + 0.005*"metadata" + 0.004*"html" + 0.004*"appdata" + 0.004*"request" + 0.004*"player" + 0.004*"explos"
#
#
# Topic: 10
# Words: 0.012*"python" + 0.007*"metadata" + 0.006*"request" + 0.006*"site" + 0.006*"lebanon" + 0.006*"output" + 0.006*"text" + 0.006*"articl" + 0.005*"code" + 0.005*"packag"
#
#
# Topic: 11
# Words: 0.008*"python" + 0.005*"execution_count" + 0.005*"metadata" + 0.004*"packag" + 0.004*"explos" + 0.004*"request" + 0.004*"sourc" + 0.004*"appdata" + 0.004*"datafram" + 0.004*"cell_typ"
#
#
# Topic: 12
# Words: 0.008*"farmer" + 0.005*"player" + 0.005*"price" + 0.005*"apmc" + 0.004*"python" + 0.004*"market" + 0.004*"privat" + 0.004*"go" + 0.004*"bill" + 0.003*"govern"
#
#
# Topic: 13
# Words: 0.010*"python" + 0.008*"execution_count" + 0.007*"request" + 0.006*"text" + 0.006*"metadata" + 0.006*"html" + 0.006*"sourc" + 0.005*"cell_typ" + 0.005*"explos" + 0.005*"beirut"
#
#
# Topic: 14
# Words: 0.010*"python" + 0.006*"metadata" + 0.006*"html" + 0.006*"packag" + 0.005*"datafram" + 0.005*"cell_typ" + 0.005*"site" + 0.005*"text" + 0.005*"request" + 0.005*"sourc"
#
#
# Topic: 15
# Words: 0.003*"python" + 0.003*"site" + 0.002*"metadata" + 0.002*"request" + 0.002*"text" + 0.002*"html" + 0.002*"code" + 0.002*"execution_count" + 0.002*"farmer" + 0.002*"appdata"
#
#
# Topic: 16
# Words: 0.008*"python" + 0.006*"metadata" + 0.006*"html" + 0.005*"text" + 0.005*"request" + 0.005*"sourc" + 0.005*"execution_count" + 0.005*"packag" + 0.005*"roam" + 0.004*"beirut"
#
#
# Topic: 17
# Words: 0.004*"python" + 0.004*"metadata" + 0.004*"request" + 0.003*"execution_count" + 0.003*"text" + 0.003*"appdata" + 0.003*"packag" + 0.003*"datafram" + 0.003*"cell_typ" + 0.003*"beirut"
#
#
# Topic: 18
# Words: 0.019*"python" + 0.013*"request" + 0.013*"import" + 0.012*"execution_count" + 0.012*"explos" + 0.011*"appdata" + 0.010*"metadata" + 0.010*"lebanon" + 0.010*"datafram" + 0.010*"sourc"
#
#
# Topic: 19
# Words: 0.008*"farmer" + 0.005*"privat" + 0.005*"apmc" + 0.005*"price" + 0.004*"player" + 0.004*"bill" + 0.004*"market" + 0.003*"concern" + 0.003*"actual" + 0.003*"python"

# %%
#extracting test set frpm the file folder
test_set=[]  #store text of all documents
for files in glob.glob('*'): #all files in the present directory
    if(files.startswith('Test')):
        handle = open(files,'r',encoding="utf-8",errors='ignore')
        test_set.append(handle.read())  
        handle.close()

# %%
test_set
# Out:
# ["There has been an uproar after the Parliament passed three agriculture related bills.\n\nThe three bills that were passed are the Farmers' Produce Trade and Commerce (Promotion and Facilitation) Bill, Farmers (Empowerment and Protection) Agreement on Price Assurance and Farm Services Bill and Essential Commodities (Amendment) Bill.\n\nThe government said that the bills would transform the agriculture sector. It would also raise the farmers' income, the Centre said. Further the government had also promised double farmers' income by 2022 and the Centre said that the Bills will make the farmer independent of government controlled markets and fetch them a better price for their produce.\n\nThe Bills propose to create a system in which the farmers and traders can sell their purchase outside the Mandis. Further it also encourage intra-state trade and this proposes to reduce the cost of transportation.\n\nFurther the Bill formulates a framework on the agreements that enable farmers to engage with agri-business companies, retailers, exporters for service and sale of produce while giving the farmer access to modern technology.\n\nIt also provides benefits for the small and marginal farmers with less than five hectares of land. The Bill also will remove items such as cereals and pulses form the list of essential commodities and attract FDI.\n\nThe farmers have been apprehensive about this Bill. They say that they are apprehensive about getting Minimum Support Price for their produce. They are also concerned about the upper hand of the agri-businesses and big retailers in negotiations.\n\nThey feel this would put them at a disadvantage.They also say that the companies may dictate the price and the benefits for small farmers may reduce the engagement of sponsors with them.\n\n"]

# %%
#processing for the test_set
processed_test=[]
for doc in test_set:
    processed_test.append(preprocess(doc))
processed_test
# Out:
# [['uproar',
#   'parliament',
#   'pass',
#   'agricultur',
#   'relat',
#   'bill',
#   'bill',
#   'pass',
#   'farmer',
#   'produc',
#   'trade',
#   'commerc',
#   'promot',
#   'facilit',
#   'farmer',
#   'empower',
#   'protect',
#   'agreement',
#   'price',
#   'assur',
#   'farm',
#   'servic',
#   'essenti',
#   'commod',
#   'amend',
#   'govern',
#   'say',
#   'bill',
#   'transform',
#   'agricultur',
#   'sector',
#   'rais',
#   'farmer',
#   'incom',
#   'centr',
#   'say',
#   'govern',
#   'promis',
#   'doubl',
#   'farmer',
#   'incom',
#   'centr',
#   'say',
#   'bill',
#   'farmer',
#   'independ',
#   'govern',
#   'control',
#   'market',
#   'fetch',
#   'better',
#   'price',
#   'produc',
#   'bill',
#   'propos',
#   'creat',
#   'farmer',
#   'trader',
#   'sell',
#   'purchas',
#   'outsid',
#   'mandi',
#   'encourag',
#   'intra',
#   'state',
#   'trade',
#   'propos',
#   'reduc',
#   'cost',
#   'transport',
#   'formul',
#   'framework',
#   'agreement',
#   'enabl',
#   'farmer',
#   'engag',
#   'agri',
#   'busi',
#   'compani',
#   'retail',
#   'export',
#   'servic',
#   'sale',
#   'produc',
#   'give',
#   'farmer',
#   'access',
#   'modern',
#   'technolog',
#   'provid',
#   'benefit',
#   'small',
#   'margin',
#   'farmer',
#   'hectar',
#   'land',
#   'remov',
#   'item',
#   'cereal',
#   'puls',
#   'form',
#   'list',
#   'essenti',
#   'commod',
#   'attract',
#   'farmer',
#   'apprehens',
#   'apprehens',
#   'get',
#   'minimum',
#   'support',
#   'price',
#   'produc',
#   'concern',
#   'upper',
#   'hand',
#   'agri',
#   'busi',
#   'retail',
#   'negoti',
#   'feel',
#   'disadvantag',
#   'compani',
#   'dictat',
#   'price',
#   'benefit',
#   'small',
#   'farmer',
#   'reduc',
#   'engag',
#   'sponsor']]

# %%
for idx, topic in lda_model.print_topics():
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.010*"farmer" + 0.007*"price" + 0.006*"apmc" + 0.006*"player" + 0.005*"market" + 0.005*"bill" + 0.004*"procur" + 0.004*"actual" + 0.004*"go" + 0.004*"govern"
#
#
# Topic: 1
# Words: 0.008*"python" + 0.006*"metadata" + 0.006*"output" + 0.006*"cell_typ" + 0.006*"text" + 0.006*"html" + 0.006*"site" + 0.006*"datafram" + 0.005*"request" + 0.005*"roam"
#
#
# Topic: 2
# Words: 0.004*"python" + 0.004*"metadata" + 0.004*"html" + 0.004*"text" + 0.003*"request" + 0.003*"execution_count" + 0.003*"datafram" + 0.003*"farmer" + 0.003*"roam" + 0.003*"cell_typ"
#
#
# Topic: 3
# Words: 0.005*"farmer" + 0.004*"bill" + 0.004*"price" + 0.004*"player" + 0.004*"apmc" + 0.003*"go" + 0.003*"privat" + 0.003*"actual" + 0.003*"python" + 0.003*"govern"
#
#
# Topic: 4
# Words: 0.031*"python" + 0.020*"metadata" + 0.019*"request" + 0.018*"html" + 0.017*"execution_count" + 0.016*"text" + 0.015*"datafram" + 0.015*"site" + 0.015*"packag" + 0.014*"output"
#
#
# Topic: 5
# Words: 0.006*"python" + 0.005*"html" + 0.005*"execution_count" + 0.005*"text" + 0.005*"request" + 0.004*"metadata" + 0.004*"datafram" + 0.004*"packag" + 0.004*"beirut" + 0.004*"roam"
#
#
# Topic: 6
# Words: 0.007*"python" + 0.006*"request" + 0.005*"lebanon" + 0.005*"farmer" + 0.005*"html" + 0.005*"packag" + 0.004*"text" + 0.004*"execution_count" + 0.004*"cell_typ" + 0.004*"code"
#
#
# Topic: 7
# Words: 0.037*"farmer" + 0.022*"player" + 0.019*"apmc" + 0.019*"price" + 0.015*"market" + 0.015*"privat" + 0.015*"bill" + 0.011*"actual" + 0.011*"go" + 0.010*"govern"
#
#
# Topic: 8
# Words: 0.006*"farmer" + 0.005*"player" + 0.004*"price" + 0.004*"bill" + 0.003*"privat" + 0.003*"apmc" + 0.003*"market" + 0.003*"actual" + 0.003*"india" + 0.003*"look"
#
#
# Topic: 9
# Words: 0.005*"python" + 0.005*"farmer" + 0.005*"datafram" + 0.005*"execution_count" + 0.005*"metadata" + 0.004*"html" + 0.004*"appdata" + 0.004*"request" + 0.004*"player" + 0.004*"explos"
#
#
# Topic: 10
# Words: 0.012*"python" + 0.007*"metadata" + 0.006*"request" + 0.006*"site" + 0.006*"lebanon" + 0.006*"output" + 0.006*"text" + 0.006*"articl" + 0.005*"code" + 0.005*"packag"
#
#
# Topic: 11
# Words: 0.008*"python" + 0.005*"execution_count" + 0.005*"metadata" + 0.004*"packag" + 0.004*"explos" + 0.004*"request" + 0.004*"sourc" + 0.004*"appdata" + 0.004*"datafram" + 0.004*"cell_typ"
#
#
# Topic: 12
# Words: 0.008*"farmer" + 0.005*"player" + 0.005*"price" + 0.005*"apmc" + 0.004*"python" + 0.004*"market" + 0.004*"privat" + 0.004*"go" + 0.004*"bill" + 0.003*"govern"
#
#
# Topic: 13
# Words: 0.010*"python" + 0.008*"execution_count" + 0.007*"request" + 0.006*"text" + 0.006*"metadata" + 0.006*"html" + 0.006*"sourc" + 0.005*"cell_typ" + 0.005*"explos" + 0.005*"beirut"
#
#
# Topic: 14
# Words: 0.010*"python" + 0.006*"metadata" + 0.006*"html" + 0.006*"packag" + 0.005*"datafram" + 0.005*"cell_typ" + 0.005*"site" + 0.005*"text" + 0.005*"request" + 0.005*"sourc"
#
#
# Topic: 15
# Words: 0.003*"python" + 0.003*"site" + 0.002*"metadata" + 0.002*"request" + 0.002*"text" + 0.002*"html" + 0.002*"code" + 0.002*"execution_count" + 0.002*"farmer" + 0.002*"appdata"
#
#
# Topic: 16
# Words: 0.008*"python" + 0.006*"metadata" + 0.006*"html" + 0.005*"text" + 0.005*"request" + 0.005*"sourc" + 0.005*"execution_count" + 0.005*"packag" + 0.005*"roam" + 0.004*"beirut"
#
#
# Topic: 17
# Words: 0.004*"python" + 0.004*"metadata" + 0.004*"request" + 0.003*"execution_count" + 0.003*"text" + 0.003*"appdata" + 0.003*"packag" + 0.003*"datafram" + 0.003*"cell_typ" + 0.003*"beirut"
#
#
# Topic: 18
# Words: 0.019*"python" + 0.013*"request" + 0.013*"import" + 0.012*"execution_count" + 0.012*"explos" + 0.011*"appdata" + 0.010*"metadata" + 0.010*"lebanon" + 0.010*"datafram" + 0.010*"sourc"
#
#
# Topic: 19
# Words: 0.008*"farmer" + 0.005*"privat" + 0.005*"apmc" + 0.005*"price" + 0.004*"player" + 0.004*"bill" + 0.004*"market" + 0.003*"concern" + 0.003*"actual" + 0.003*"python"
